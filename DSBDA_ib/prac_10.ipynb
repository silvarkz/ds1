# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Iris.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.mean()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_7504\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_7504\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
df.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           5.0          3.0           1.5          0.2      Iris-setosa
# 1           NaN          NaN           NaN          NaN  Iris-versicolor
# 2           NaN          NaN           NaN          NaN   Iris-virginica

# %%
df.std()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_7504\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# sepal_length    0.828066
# sepal_width     0.433594
# petal_length    1.764420
# petal_width     0.763161
# dtype: float64

# %%
df.min()
# Out:
# sepal_length            4.3
# sepal_width             2.0
# petal_length            1.0
# petal_width             0.1
# species         Iris-setosa
# dtype: object

# %%
df.max()
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %%
df.var()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_7504\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# sepal_length    0.685694
# sepal_width     0.188004
# petal_length    3.113179
# petal_width     0.582414
# dtype: float64

# %%
plt.hist(['sepal_length'])
plt.show()

# %%
plt.figure(figsize=(10,7))
df.boxplot()
plt.show()

# %%
fig, axes = plt.subplots (2, 2, figsize=(16,8))

axes[0,0].set_title("Distribution of Sepal Length") 
axes[0,0].hist(df["sepal_length"]);
axes[0,1].set_title("Distribution of Sepal width")
axes[0,1].hist (df["sepal_width"]);
axes[1,0].set_title("Distribution of Petal Length") 
axes[1,0].hist(df["petal_length"]); 
axes [1,1].set_title("Distribution of Petal Width")
axes[1,1].hist(df["petal_width"]);
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16,9))
axes[0,0].set_title("Distribution of Sepal Length")
sns.boxplot (y="sepal_length", x="species", data=df, orient='v', ax=axes[0,0]) 
axes[0,1].set_title("Distribution of Sepal width")
sns.boxplot(y="sepal_width",x="species",data=df,orient='v',ax=axes[0,1])
axes[1,0].set_title("Distribution of petal Length ")
sns.boxplot (y="petal_length", x="species", data=df, orient="v", ax=axes[1,0])
axes[1,1].set_title("Distribution of petal width") 
sns.boxplot(y="petal_width",x="species",data=df,orient='v',ax=axes[1,1])
plt.show()
